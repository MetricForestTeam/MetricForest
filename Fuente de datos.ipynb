# %%
#Ánalisis de Datos para Abundancia y Dominancia

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
prueba=pd.read_csv("prueba.csv")

# %%
prueba
# Out:
#      Sector  Grupo  Sendero  Distancia  Parcela  Árbol    Especie   DAP  \
# 0         1      1        2        150        1      1     Encino   5.1
# 1         1      1        2        150        1      2     Encino   9.4
# 2         1      1        2        150        1      3      Roble  25.6
# 3         1      1        2        150        1      4      Nance   6.7
# 4         1      1        2        150        1      5      Roble  23.3
# ..      ...    ...      ...        ...      ...    ...        ...   ...
# 520       3     10       26         10        5      9     Encino   9.5
# 521       3     10       26         10        5     10     Carbón   8.0
# 522       3     10       26         10        5     11     Carbón   5.3
# 523       3     10       26         10        5     12     Encino   9.5
# 524       3     10       26         10        5     13  Molinillo   9.5
#
#         HT      HC   LD        AB
# 0      4.91  1.7900   0  0.002043
# 1      7.77  3.0700   0  0.006940
# 2     11.91  6.7900   1  0.051472
# 3      7.58     NaN   0  0.003526
# 4     11.94  6.0600   0  0.042638
# ..      ...     ...  ..       ...
# 520  5.6261  3.0480   0  0.007088
# 521  5.2451     NaN   0  0.005027
# 522  3.2131     NaN   0  0.002206
# 523  6.6421  2.1336   1  0.007088
# 524  4.4704     NaN   0  0.007088
#
# [525 rows x 12 columns]

# %%
type(prueba)
# Out:
# pandas.core.frame.DataFrame

# %%
grafica = prueba.groupby(["Especie", "Sector"], sort=False,)["DAP"].max()
grafica.unstack().T.plot(kind="bar", subplots=False, layout=(2,2), figsize=(20,10), fontsize=(25))
# Out:
# <AxesSubplot:xlabel='Sector'>

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#Comparación de diametro con altura según parcelas
df = pd.DataFrame({'Parcela':['1', '2', '3', '4', '5'], 
                   'DAP':[16.08, 15.76, 11.49, 16.39, 18.16], 
                   'HT':[5.39, 5.44, 7.79, 7.61, 8.422]})

df = df.set_index('Parcela')
fig, ax = plt.subplots()
df.plot(ax = ax) 
plt.show()

plt.rcParams['figure.figsize'] = [3,3]

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-pastel')

#Comparación de diametro con altura según parcelas
fig, ax = plt.subplots(2, 2, sharey = True)
parcela = ['1', '2', '3', '4', '5']
parámetro = {'DAP':[16.08, 15.76, 11.49, 16.39, 18.16], 'HT':[5.39, 5.44, 7.79, 7.61, 8.422]}
ax[0, 0].plot(parcela, parámetro['DAP'], color = 'tab:green')
ax[0, 1].plot(parcela, parámetro['HT'], color = 'tab:olive')
ax[1, 0].bar(parcela, parámetro['DAP'], color = 'tab:green')
ax[1, 1].bar(parcela, parámetro['HT'], color = 'tab:olive')

plt.show()

plt.rcParams['figure.figsize'] = [4,3]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')


# Porcentaje de árboles con caracteristicas deseables y no deseables
x = [481,41]
colors = plt.get_cmap('GnBu')(np.linspace(0.2, 0.7, len(x)))

# plot
fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=2, center=(2,2),
       wedgeprops={"linewidth": 3, "edgecolor": "white"}, frame=True)

ax.set(xlim=(0, 4), xticks=np.arange(1, 4),
       ylim=(0, 4), yticks=np.arange(1, 4))

plt.show()

# %%
#Especies más abundantes
##Encino(228), Roble(179)

import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x = np.linspace(-179, 228, 100)
y = np.linspace(-179, 228, 100)
x, y = np.meshgrid(x, y)
z = np.sqrt(x**2 + 2*y**2)
ax.contourf(x, y, z, cmap='Greens')

plt.contourf(X, Y, Z, cmap='Greens')
plt.colorbar();

plt.rcParams['figure.figsize'] = [4,3]
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('bosque.jpg')
print(img)
# Out:
# [[[197 209   1]
#   [192 199  43]
#   [190 196  74]
#   ...
#   [210 226  14]
#   [224 241   2]
#   [235 244  31]]
#
#  [[184 198   0]
#   [181 188  20]
#   [156 162  28]
#   ...
#   [206 217  37]
#   [223 236  25]
#   [236 243  52]]
#
#  [[193 206   0]
#   [201 210  21]
#   [177 184  29]
#   ...
#   [196 203  63]
#   [217 225  54]
#   [232 237  75]]
#
#  ...
#
#  [[129 104  63]
#   [134 110  72]
#   [ 94  74  41]
#   ...
#   [105  73  32]
#   [113  78  40]
#   [120  80  44]]
#
#  [[116  91  51]
#   [111  87  51]
#   [ 91  70  41]
#   ...
#   [131  99  58]
#   [132  97  57]
#   [134  94  58]]
#
#  [[ 98  74  38]
#   [ 74  51  19]
#   [ 76  55  28]
#   ...
#   [156 124  83]
#   [143 108  68]
#   [133  93  57]]]

# %%
imgplot = plt.imshow(img)

# %%
lum_img = img[:, :, 0]

plt.imshow(lum_img)
plt.imshow(lum_img, cmap="hot")
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
import pandas as pd
from matplotlib import pyplot as plt
prueba=pd.read_csv("prueba.csv")
prueba
# Out:
#      Sector  Grupo  Sendero  Distancia  Parcela  Árbol    Especie   DAP  \
# 0         1      1        2        150        1      1     Encino   5.1
# 1         1      1        2        150        1      2     Encino   9.4
# 2         1      1        2        150        1      3      Roble  25.6
# 3         1      1        2        150        1      4      Nance   6.7
# 4         1      1        2        150        1      5      Roble  23.3
# ..      ...    ...      ...        ...      ...    ...        ...   ...
# 520       3     10       26         10        5      9     Encino   9.5
# 521       3     10       26         10        5     10     Carbón   8.0
# 522       3     10       26         10        5     11     Carbón   5.3
# 523       3     10       26         10        5     12     Encino   9.5
# 524       3     10       26         10        5     13  Molinillo   9.5
#
#         HT      HC   LD        AB
# 0      4.91  1.7900   0  0.002043
# 1      7.77  3.0700   0  0.006940
# 2     11.91  6.7900   1  0.051472
# 3      7.58     NaN   0  0.003526
# 4     11.94  6.0600   0  0.042638
# ..      ...     ...  ..       ...
# 520  5.6261  3.0480   0  0.007088
# 521  5.2451     NaN   0  0.005027
# 522  3.2131     NaN   0  0.002206
# 523  6.6421  2.1336   1  0.007088
# 524  4.4704     NaN   0  0.007088
#
# [525 rows x 12 columns]

# %%
Encino=prueba[prueba.Especie=="Encino"]
Encino
# Out:
#      Sector  Grupo  Sendero  Distancia  Parcela  Árbol Especie   DAP     HT   \
# 0         1      1        2        150        1      1  Encino   5.1    4.91
# 1         1      1        2        150        1      2  Encino   9.4    7.77
# 5         1      1        2        170        3      1  Encino  10.3    8,80
# 6         1      1        2        170        3      2  Encino   5.6    3,99
# 7         1      1        2        170        3      3  Encino   6.6    6.03
# ..      ...    ...      ...        ...      ...    ...     ...   ...     ...
# 516       3     10       26         10        5      5  Encino   9.7  5.8928
# 518       3     10       26         10        5      7  Encino   7.5  4.0894
# 519       3     10       26         10        5      8  Encino   6.3  5.1689
# 520       3     10       26         10        5      9  Encino   9.5  5.6261
# 523       3     10       26         10        5     12  Encino   9.5  6.6421
#
#         HC   LD        AB
# 0    1.7900   0  0.002043
# 1    3.0700   0  0.006940
# 5    3.9900   0  0.008332
# 6    1.9200   0  0.002463
# 7    0.9000   0  0.003421
# ..      ...  ..       ...
# 516     NaN   0  0.007390
# 518  1.8288   0  0.004418
# 519     NaN   0  0.003117
# 520  3.0480   0  0.007088
# 523  2.1336   1  0.007088
#
# [227 rows x 12 columns]

# %%
Roble=prueba[prueba.Especie=="Roble"]
Roble
# Out:
#      Sector  Grupo  Sendero  Distancia  Parcela  Árbol Especie   DAP      HT   \
# 2         1      1        2        150        1      3   Roble  25.6    11.91
# 4         1      1        2        150        1      5   Roble  23.3    11.94
# 10        1      1        2        170        3      6   Roble  15.8     8.99
# 18        1      1        2        180        4      1   Roble   8.1     5.51
# 20        1      1        2        180        4      3   Roble  37.0    12.85
# ..      ...    ...      ...        ...      ...    ...     ...   ...      ...
# 501       3     10       25        150        3      7   Roble  31.7  12.9286
# 506       3     10       26          0        4      5   Roble   9.3   5.5626
# 507       3     10       26          0        4      6   Roble   8.3   5.3467
# 508       3     10       26          0        4      7   Roble   5.7   5.1816
# 509       3     10       26          0        4      8   Roble   7.2   4.9784
#
#         HC   LD        AB
# 2    6.7900   1  0.051472
# 4    6.0600   0  0.042638
# 10   2.1600   1  0.019607
# 18   1.8800   0  0.005153
# 20   5.0000   1  0.107521
# ..      ...  ..       ...
# 501  5.3340   1  0.078924
# 506  2.2733   1  0.006793
# 507  2.7051   0  0.005411
# 508  2.0828   0  0.002552
# 509  3.0099   0  0.004072
#
# [178 rows x 12 columns]

# %%
plt.plot(Encino.Sector, Encino.LD)
plt.plot(Roble.Sector, Roble.LD)
plt.legend(["Encino", "Roble"])
plt.xlabel("Sector")
plt.ylabel("LD")
plt.show()

# %%
plt.plot(Encino.Sector, Encino.Grupo/1)
plt.plot(Roble.Sector, Roble.Grupo/1)
plt.legend(["Encino", "Roble"])
plt.xlabel("Sector")
plt.ylabel("Grupo")
plt.show()
